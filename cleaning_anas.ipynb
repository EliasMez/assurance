# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
from math import log as ln

# %%
df = pd.read_csv("assurance.csv")

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
barplot_msno= msno.bar(df)

# %% [markdown]
# On peut observer qu'il n'y a donc aucune valeur manquante. Nous avons ,ceci dit, un doublon
